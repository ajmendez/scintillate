# %%
import json
from pprint import pprint
from pysurvey.plot import setup, line, legend, box
from pysurvey import plot as plt
import matplotlib.dates
from datetime import datetime

# %%
data = json.load(open('/Users/ajmendez/data/flickr/stats.json','r'))
print data.keys()[:10]
pprint(data['2014-01-15'].keys())
# Out:
# [u'2014-03-13', u'2014-05-12', u'2014-06-05', u'2014-03-12', u'2014-04-02', u'2014-03-11', u'2014-05-14', u'2014-04-16', u'2014-04-17', u'2014-04-14']
# [u'domainlist',
#  u'galleries',
#  u'photos',
#  u'collections',
#  u'sets',
#  u'domains',
#  u'total',
#  u'photolist',
#  u'photostream']

# %%
keys = sorted([k for k in data.keys() if '-' in k])
dates = [datetime.strptime(k, '%Y-%m-%d') for k in keys]
#x=dates
x = matplotlib.dates.date2num(dates)
y = [data[k]['total'] for k in keys]

#print sorted(keys)
#print x,y
plt.setup(figsize=(18,6), subplt=(1,3,1))
plot_date(x,y, '-s')

plt.setup(subplt=(1,3,2), ylog=True)
plot_date(x,y, '-s')

plt.setup(subplt=(1,3,3), 
          xr=[1,1400], xlog=True, xlabel='Distribution of Total Views')
hist(y, np.logspace(0,3,15))

fig = pylab.gcf()
fig.autofmt_xdate()

# %%
ii = argmax(y)
print y[ii], dates[ii]
ii = argmin(x)
print y[ii], dates[ii]
ii = argmax(x)
print y[ii], dates[ii]
# Out:
# 1882 2014-02-03 00:00:00
# 17 2013-11-11 00:00:00
# 267 2014-06-23 00:00:00

# %%
def fitrange(x,y, xr, **kwargs):
    x = date2num(x)
    xr = date2num(xr)
    
    ii = np.where( (x > xr[0]) & (x < xr[1]))
    a,b = np.polyfit(x[ii],y[ii],1)
    z = a*x+b+offset # offset to align data to bulk of points
    tmp = dict(label='Linear fit: m={:0.0f}#/day'.format(a))
    tmp.update(kwargs)
    pylab.plot(dates, z, **tmp)
    box(x=xr, alpha=0.2, zorder=-1)
    

offset = 0 #800
y = [data[k]['total'] for k in keys]
y = np.cumsum(y)

setup(figsize=(12,6), subplt=(1,2,1))
pylab.plot(dates,y, label='Cumulative Number')
# fitrange(dates, y, [datetime(2013,11,22), datetime(2013,12,13)])
fitrange(dates, y, [datetime(2014,2,9), datetime(2014,4,10)])
fitrange(dates, y, [datetime(2014,4,25), datetime(2014,6,15)])
legend(loc=2)
setup(embiggenx=[0,0.1])

setup(subplt=(1,2,2), ylog=True)
pylab.plot(dates,y)
pylab.plot(dates,z)

fig = pylab.gcf()
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5513d8fabec0> in <module>()
#      26 setup(subplt=(1,2,2), ylog=True)
#      27 pylab.plot(dates,y)
# ---> 28 pylab.plot(dates,z)
#      29
#      30 fig = pylab.gcf()
#
# NameError: name 'z' is not defined

# %%
from scipy import signal
x = matplotlib.dates.date2num(dates)
y = np.array([data[k]['total'] for k in keys])

hz = 1.0 # 1.0/(24*60*6)

setup(figsize=(6,6), 
      xlabel='Period [day]', xlog=True,
      xr=[1.2, 400], xtickv=[1,10,100,1000],
      xticknames='1 10 100 1000'.split(),
      ylabel='Spectrum', ylog=True)
out = []
for i in range(300):
    ii = np.random.random_integers(0,len(y)-1, int(0.5*len(y)))
    z = np.zeros(len(y))
    z[ii] = y[ii]
    f, Pxx = signal.periodogram(z, hz, scaling='spectrum')
    out.append(Pxx)
    plot(1/f, Pxx, ',k', alpha=0.2)
sm = np.mean(np.array(out), axis=0)

f, Pxx = signal.periodogram(y, hz, scaling='spectrum')
plot(1/f, Pxx, color='b', alpha=0.2);
# plot(1/f, sm);



c = np.log10(1/f)[1:]
bins = np.linspace(np.min(c), np.max(c), 20)
out = []
for xmin, xmax in zip(bins, bins[1:]):
    ii = np.where( (c >= xmin) & (c <= xmax) )[0]
#     print xmin, xmax, len(ii)
    out.append([10**np.mean(c[ii]), np.mean(Pxx[1:][ii])])
xx,yy = map(np.array, zip(*out))
plot(xx,yy, '.r');
maxpt = xx[np.argsort(yy)[::-1]][2:5]
line(x=maxpt)
print maxpt
# Out:
# -c:19: RuntimeWarning: divide by zero encountered in divide
# -c:23: RuntimeWarning: divide by zero encountered in divide
# -c:28: RuntimeWarning: divide by zero encountered in divide
# /Users/ajmendez/.local/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /Users/ajmendez/.local/lib/python2.7/site-packages/numpy/core/_methods.py:67: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python2.7/site-packages/matplotlib/scale.py:97: RuntimeWarning: invalid value encountered in less_equal
#   a[a <= 0.0] = 1e-300
# [ 16.72424592  75.          10.02899332]

# %%
plot(x,y)
t = np.abs(np.diff(y))
ii = np.argsort(t)[::-1]


plot(x[1:], -t)
G = x[1:][ii[:20]]
line(x=G, zorder=-1)
setup(figsize=(6,6))
hist(np.abs(np.array([G-g for g in G]).flatten()), 20);
